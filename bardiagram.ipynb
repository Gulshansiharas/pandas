# %%
import matplotlib.pyplot as plt

# %%
Categories=['category1','category2','category3']
values=[10,11,13]

# %%
plt.bar(Categories,values,color='green')
plt.xlabel('Categories')
plt.ylabel('values')
plt.title('BARDIAGRAM')
plt.show()
