# %%
import pandas as pd

# %%
data1=pd.DataFrame({'Category A':[12,34,56],'Category B':[76,46,23],'Category C':[25,76,55]},index=['a','v','c'])

# %%
data1
# Out:
#    Category A  Category B  Category C
# a          12          76          25
# v          34          46          76
# c          56          23          55

# %%
data2=pd.DataFrame({'Category D':[6,34,56],'Category E':[98,24,12],'Category F ':[25,76,55]},index=['a','b','c'])

# %%
data2
# Out:
#    Category D  Category E  Category F
# a           6          98           25
# b          34          24           76
# c          56          12           55

# %%
data1.join(data2).fillna('feroz')
# Out:
#    Category A  Category B  Category C Category D Category E Category F
# a          12          76          25        6.0       98.0        25.0
# v          34          46          76      feroz      feroz       feroz
# c          56          23          55       56.0       12.0        55.0

# %%
data1.join(data2,how='left')
# Out:
#    Category A  Category B  Category C  Category D  Category E  Category F
# a          12          76          25         6.0        98.0         25.0
# v          34          46          76         NaN         NaN          NaN
# c          56          23          55        56.0        12.0         55.0

# %%
data1.join(data2,how='right')
# Out:
#    Category A  Category B  Category C  Category D  Category E  Category F
# a        12.0        76.0        25.0           6          98           25
# b         NaN         NaN         NaN          34          24           76
# c        56.0        23.0        55.0          56          12           55

# %%
data1.join(data2,how='inner')
# Out:
#    Category A  Category B  Category C  Category D  Category E  Category F
# a          12          76          25           6          98           25
# c          56          23          55          56          12           55

# %%
data1.join(data2,how='outer')
# Out:
#    Category A  Category B  Category C  Category D  Category E  Category F
# a        12.0        76.0        25.0         6.0        98.0         25.0
# b         NaN         NaN         NaN        34.0        24.0         76.0
# c        56.0        23.0        55.0        56.0        12.0         55.0
# v        34.0        46.0        76.0         NaN         NaN          NaN
